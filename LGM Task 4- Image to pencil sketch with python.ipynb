# %% [markdown]
# # Task 4 :- Image to Pencil Sketch with Python(Beginner Level):

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic
# black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our
# inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing
# the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry
# image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library
# in Python.

# %% [markdown]
# Reference: https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/

# %% [markdown]
# # Suraj Jagtap

# %% [markdown]
# Data Science Intern at LetsGrowMore (LGMVIP)

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# # Read the image in RBG format

# %%
image = cv2.imread("C:\\Users\\dhira\\OneDrive\\Pictures\\Flower.jpg")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=800x531 at 0x15ECF1B68E0>

# %% [markdown]
# # Create a new image by converting the original image to greyscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x15ED08E4C40>

# %% [markdown]
# This turned the image into a classic black and white photo. Then the next thing to do is invert the
# grayscale image also called negative image, this will be our inverted grayscale image

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x15ED08EEA30>

# %% [markdown]
# # Now convert Negative image into blurry image

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x15ED08737C0>

# %% [markdown]
# # Create the pencil sketch by mixing the grayscale image with the inverted blurry image

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=250.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=800x531 at 0x15ED08E4C40>

# %% [markdown]
# # Thank you
